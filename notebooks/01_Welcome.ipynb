# %% [markdown]
# # Welcome to the Introduction to Deep Learning course
# Nice to see you in this course.
# Let me give you a quick introduction to JupyterLab.

# %% [markdown]
# You are accessing the Vienna Scientific Cluster via its JupyterHub. You've been allocated a NVIDIA A100 GPU throughout this course.
# Let's see, if we can display what we have. To do so, run the following code cell by pressing shift and enter.

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# 2025-11-03 09:46:04.439174: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-11-03 09:46:04.439264: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-11-03 09:46:04.446463: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-11-03 09:46:04.471776: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %% [markdown]
# You can also find information about your GPU using `!nvidia-smi`. Whenever you use an exclamation mark at the beginning of a line of code, you can enter commands for the command line.

# %%
# !nvidia-smi
# Out:
# Mon Nov  3 09:46:11 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 545.23.08              Driver Version: 545.23.08    CUDA Version: 12.3     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA A40                     Off | 00000000:41:00.0 Off |                    0 |
# |  0%   36C    P0              75W / 300W |      7MiB / 46068MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# If you have access to a GPU, TensorFlow will automatically use it whenever possible.

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Let's take notes
